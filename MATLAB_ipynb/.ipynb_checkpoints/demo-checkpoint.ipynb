% %% [markdown]
% ### test demo for using MATLAB code in Jupyter notebook

% %%
x = 0:0.1:2*pi;
y = sin(x);
figure;
fig = figure('Visible', 'on');
plot(x, y, 'b-', 'LineWidth', 2);
title('正弦函数图像');
xlabel('x');
ylabel('sin(x)');
grid on;
workspace

% %%
c = 9;
